# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import numpy as np
import statistics as sts

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis,y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, marker="+",color="red",linewidth=2,label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
plt.xlim(0,5)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis,marker="D",color="Green", linewidth=2,label="Boston")
ax.set_xlabel("Date")
ax.set_ylabel("Fares($)")
ax.set_title("Pyber Fares by")
ax.legend("Boston")
ax.grid()

# %%
plt.bar(x_axis,y_axis, color="Green",label="Boston")
plt.xlabel("Date")
plt.ylabel("Fare($)")
plt.title("PyBer Fare by Month")
plt.legend()

# %%
plt.barh(x_axis,y_axis, color="magenta",label="Boston")
plt.gca().invert_yaxis()
plt.xlabel("Fares($)")
plt.ylabel("Dates")
plt.title("PyBer Fares by Month")
plt.legend()

# %%
fig, ax = plt.subplots()
ax.bar(x_axis,y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
fig, ax = plt.subplots()
ax.barh(x_axis,y_axis, color='cyan', label="Chicago")
ax.invert_yaxis()
ax.set_xlabel("Fares($)")
ax.set_ylabel("Date")
ax.legend()

# %%
plt.scatter(y_axis,x_axis, c="red", label="Chicago")
plt.xlabel("Fare($)")
plt.xlim(0,50)
plt.ylabel("Date")
plt.title("PyBer Fare by Month")
plt.legend()

# %%
"""longer form way:
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)"""
    
plt.scatter(x_axis,y_axis,s=[i*3 for i in y_axis])

# %%
fig, ax = plt.subplots()
ax.scatter(y_axis,x_axis,color="skyblue", s=[i*5 for i in y_axis], alpha=.8,linewidth=2,edgecolors="black")
ax.invert_yaxis()
ax.set_xlim(0,50)
ax.set_xlabel('Fares($)')
ax.set_ylabel('Date')
ax.set_title("Fares by Month")
# Out:
# Text(0.5, 1.0, 'Fares by Month')

# %%
# color change on labels for dark mode
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8,8)) # ----> Why did this need to be before?
plt.pie(y_axis,explode=explode_values,labels=x_axis,colors=colors,autopct='%.1f%%')

plt.plot()
# Out:
# []

# %%
explode_values2 = (0, 0, .2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
color_set = ["red",'coral','orange','gold','yellow','olive','green','teal','blue','slateblue','indigo','violet']

fig, ax = plt.subplots()
ax.pie(y_axis,explode=explode_values2,colors=color_set,labels=x_axis,shadow=True,startangle=90,autopct='%.1f%%',counterclock=False)
fig.set_size_inches(8,8)
ax.plot()
# Out:
# []

# %%
stdev = sts.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
plt.errorbar(x_axis,y_axis, yerr=stdev, capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
fi, ax = plt.subplots()
ax.errorbar(x_axis,y_axis, yerr=stdev,capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.bar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.barh(x_axis,y_axis)
plt.xticks(np.arange(0,51,step=5.0))
plt.gca().invert_yaxis()

# %%
fi,ax = plt.subplots()
ax.barh(x_axis,y_axis,xerr=stdev, capsize=3)
ax.set_xticks(np.arange(0,50,step=7.5))
ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.plot()
# Out:
# []
